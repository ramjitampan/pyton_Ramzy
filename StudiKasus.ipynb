# %% [markdown]
# <a href="https://colab.research.google.com/github/ramjitampan/pyton_Ramzy/blob/main/StudiKasus.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install pandas numpy

# %%
import pandas as pd
from google.colab import drive
drive.mount('/content/drive')  # Ikuti tautan untuk login & izin

import pandas as pd
path = "/content/drive/MyDrive/Colab Notebooks/titanic.csv"
data = pd.read_csv(path)
data_series = pd.Series(data['Name'])
print(data_series.head())
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# 0                              Braund, Mr. Owen Harris
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2                               Heikkinen, Miss. Laina
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4                             Allen, Mr. William Henry
# Name: Name, dtype: object

# %%
data_series.tail()
# Out:
# a     2
# b     4
# c     6
# d     8
# e    10
# dtype: int64

# %%
print(data_series[100])

print(data_series[200])
# Out:
# Petranec, Miss. Matilda
# Vande Walle, Mr. Nestor Cyriel

# %%
print(data_series.loc[100])
print(data_series.loc[200])
# Out:
# Petranec, Miss. Matilda
# Vande Walle, Mr. Nestor Cyriel

# %%
import pandas as pd

data = {'satu':[1,1,1,1,1],
        'dua': [2,2,2,2,2],
        'tiga':[3,3,3,3,3]}

df = pd.DataFrame(data)
df.head()
# Out:
#    satu  dua  tiga
# 0     1    2     3
# 1     1    2     3
# 2     1    2     3
# 3     1    2     3
# 4     1    2     3

# %%
import pandas as pd

data = {'satu':[1,1,1,1,1],
        'dua': [2,2,2,2,2],
        'tiga':[3,3,3,3,3]}

df = pd.DataFrame(data, index=['a', 'b', 'c', 'd', 'e'])
df.head()
# Out:
#    satu  dua  tiga
# a     1    2     3
# b     1    2     3
# c     1    2     3
# d     1    2     3
# e     1    2     3

# %%
import pandas as pd

data = [{'satu':1, 'dua':2, 'tiga':3},      # index ke-0
        {'satu':1, 'dua':2, 'tiga':3},      # index ke-1
        {'satu':1, 'dua':2, 'tiga':3}]      # index ke-2

df = pd.DataFrame(data)
df.head()
# Out:
#    satu  dua  tiga
# 0     1    2     3
# 1     1    2     3
# 2     1    2     3

# %%
import pandas as pd

data = [{'satu':1, 'dua':2, 'tiga':3},      # index ke-0
        {'satu':1, 'dua':2, 'tiga':3},      # index ke-1
        {'satu':1, 'dua':2, 'tiga':3}]      # index ke-2

df = pd.DataFrame(data)
df.head()
# Out:
#    satu  dua  tiga
# 0     1    2     3
# 1     1    2     3
# 2     1    2     3

# %%
import pandas as pd

data = {'satu':pd.Series([1,1,1,1,1]),
        'dua': pd.Series([2,2,2,2,2]),
        'tiga':pd.Series([3,3,3,3,3])}

df = pd.DataFrame(data,)
df.head()
# Out:
#    satu  dua  tiga
# 0     1    2     3
# 1     1    2     3
# 2     1    2     3
# 3     1    2     3
# 4     1    2     3

# %%
df = pd.read_csv(r'/content/drive/MyDrive/Colab Notebooks/titanic.csv')
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
df = pd.read_csv(r'/content/drive/MyDrive/Colab Notebooks/titanic.csv')
df_baru = df
df_baru.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
df = pd.read_csv(r'/content/drive/MyDrive/Colab Notebooks/titanic.csv')
df['Name']
# Out:
# 0                                Braund, Mr. Owen Harris
# 1      Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2                                 Heikkinen, Miss. Laina
# 3           Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4                               Allen, Mr. William Henry
#                              ...
# 886                                Montvila, Rev. Juozas
# 887                         Graham, Miss. Margaret Edith
# 888             Johnston, Miss. Catherine Helen "Carrie"
# 889                                Behr, Mr. Karl Howell
# 890                                  Dooley, Mr. Patrick
# Name: Name, Length: 891, dtype: object

# %%
df[['Name', 'Sex']]
# Out:
#                                                   Name     Sex
# 0                              Braund, Mr. Owen Harris    male
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female
# 2                               Heikkinen, Miss. Laina  female
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female
# 4                             Allen, Mr. William Henry    male
# ..                                                 ...     ...
# 886                              Montvila, Rev. Juozas    male
# 887                       Graham, Miss. Margaret Edith  female
# 888           Johnston, Miss. Catherine Helen "Carrie"  female
# 889                              Behr, Mr. Karl Howell    male
# 890                                Dooley, Mr. Patrick    male
#
# [891 rows x 2 columns]

# %%
df.loc[10]
# Out:
# PassengerId                                 11
# Survived                                     1
# Pclass                                       3
# Name           Sandstrom, Miss. Marguerite Rut
# Sex                                     female
# Age                                        4.0
# SibSp                                        1
# Parch                                        1
# Ticket                                 PP 9549
# Fare                                      16.7
# Cabin                                       G6
# Embarked                                     S
# Name: 10, dtype: object

# %%
df.loc[:10]
# Out:
#     PassengerId  Survived  Pclass  \
# 0             1         0       3
# 1             2         1       1
# 2             3         1       3
# 3             4         1       1
# 4             5         0       3
# 5             6         0       3
# 6             7         0       1
# 7             8         0       3
# 8             9         1       3
# 9            10         1       2
# 10           11         1       3
#
#                                                  Name     Sex   Age  SibSp  \
# 0                             Braund, Mr. Owen Harris    male  22.0      1
# 1   Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                              Heikkinen, Miss. Laina  female  26.0      0
# 3        Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                            Allen, Mr. William Henry    male  35.0      0
# 5                                    Moran, Mr. James    male   NaN      0
# ...

# %%
df[['Name', 'Sex', 'Age', 'Survived', 'Embarked']][10:15]
# Out:
#                                     Name     Sex   Age  Survived Embarked
# 10       Sandstrom, Miss. Marguerite Rut  female   4.0         1        S
# 11              Bonnell, Miss. Elizabeth  female  58.0         1        S
# 12        Saundercock, Mr. William Henry    male  20.0         0        S
# 13           Andersson, Mr. Anders Johan    male  39.0         0        S
# 14  Vestrom, Miss. Hulda Amanda Adolfina  female  14.0         0        S

# %%
pd.read_csv(r'/content/drive/MyDrive/Colab Notebooks/data.csv')
# Out:
#     Name;Address
# 0  Faqih;Bandung
# 1    Ina;Jakarta
# 2  Doni;Surabaya
# 3      Roni;Bali

# %%
pd.read_csv(r'/content/drive/MyDrive/Colab Notebooks/data.csv', sep=';')
# Out:
#     Name   Address
# 0  Faqih   Bandung
# 1    Ina   Jakarta
# 2   Doni  Surabaya
# 3   Roni      Bali

# %%
pd.read_csv(r'/content/drive/MyDrive/Colab Notebooks/data.csv', sep=';', header=None)
# Out:
#        0         1
# 0   Name   Address
# 1  Faqih   Bandung
# 2    Ina   Jakarta
# 3   Doni  Surabaya
# 4   Roni      Bali

# %%
pd.read_csv(r'/content/drive/MyDrive/Colab Notebooks/data.csv', sep=';', names=['Name', 'Address'])
# Out:
#     Name   Address
# 0   Name   Address
# 1  Faqih   Bandung
# 2    Ina   Jakarta
# 3   Doni  Surabaya
# 4   Roni      Bali

# %%
pd.read_json(r'/content/drive/MyDrive/Colab Notebooks/data.json')
# Out:
#     Name  Address
# 0  Faqih  Bandung
# 1    Ina  Jakarta
# 2   Donu  Bandung
# 3   Roni     Bali

# %%
import pandas as pd

data = pd.read_json(r'/content/drive/MyDrive/Colab Notebooks/data.json')
print(data)
# Out:
#     Name  Address
# 0  Faqih  Bandung
# 1    Ina  Jakarta
# 2   Donu  Bandung
# 3   Roni     Bali

# %%
pd.read_excel(r'/content/drive/MyDrive/Colab Notebooks/data.xlsx')
# Out:
#     Name   Address
# 0  Faqih   Bandung
# 1    Ina   Jakarta
# 2   Doni  Surabaya
# 3   Rono      Bali

# %%
pd.read_html(r'/content/drive/MyDrive/Colab Notebooks/data.html')
# Out:
# [       0        1
#  0  Faqih  Bandung]

# %%
pd.read_html(r'/content/drive/MyDrive/Colab Notebooks/data.html')[0]
# Out:
#        0        1
# 0  Faqih  Bandung

# %%
url = "https://ngodingdata.com/tutorial-mongodb-memahami-konsep-database-nosql/"

# %%
import pandas as pd
pd.read_html(url, header=0)[0]
# Out:
#            Unnamed: 0                                Database Relasional  \
# 0  Waktu Pengembangan                               Sekitar Tahun 1970an
# 1          Model Data  Satu jenis (setiap entitas mempunyai relasi de...
# 2               Skema  Mempunyai struktur skema yang tetap dan diinis...
# 3        Skalabilitas  Secara vertikal, artinya satu server harus dib...
# 4     Manipulasi Data  Bahasa tertentu menggunakan pernyataan Select,...
# 5     Contoh Database       MySQL, MariaDB, Postgres, Oracle, SQL Server
#
#                                       Database NoSQL
# 0                               Sekitar Tahun 2000an
# 1  Banyak jenis (key-value, document, graph, colu...
# 2  Mempunyai jenis skema yang fleksibel dengan st...
# 3  Secara horizontal, artinya untuk menambah kapa...
# 4                       Melalui object-oriented APIs
# 5        MongoDB, Couchbase, Hbase, Neo4j, DynamoDB,
